# %%
import os
from glob import glob
import pandas as pd
from functools import reduce
from xml.etree import ElementTree as et
from shutil import move

# %%
# Load all XML annotation files from the specified directory
# This directory contains images and corresponding annotation files (.xml)
xml_files = glob('./datasets/images/*.xml')

# %%
# Data cleaning: replace backslashes (\\) with forward slashes (/)
# Useful when working with file paths on different operating systems
replace_text = lambda x: x.replace('\\', '/')
xml_files = list(map(replace_text, xml_files))

# %%
# Print the list of XML files loaded (for debugging)
xml_files
# Out:
# ['./datasets/images/thyrocare_0_122.xml',
#  './datasets/images/thyrocare_0_1374.xml',
#  './datasets/images/thyrocare_0_1433.xml',
#  './datasets/images/thyrocare_0_1861.xml',
#  './datasets/images/thyrocare_0_2177.xml',
#  './datasets/images/thyrocare_0_2300.xml',
#  './datasets/images/thyrocare_0_2505.xml',
#  './datasets/images/thyrocare_0_2649.xml',
#  './datasets/images/thyrocare_0_2737.xml',
#  './datasets/images/thyrocare_0_2841.xml',
#  './datasets/images/thyrocare_0_2866.xml',
#  './datasets/images/thyrocare_0_2885.xml',
#  './datasets/images/thyrocare_0_3439.xml',
#  './datasets/images/thyrocare_0_3558.xml',
#  './datasets/images/thyrocare_0_3804.xml',
#  './datasets/images/thyrocare_0_3813.xml',
#  './datasets/images/thyrocare_0_421.xml',
#  './datasets/images/thyrocare_0_4468.xml',
#  './datasets/images/thyrocare_0_447.xml',
#  './datasets/images/thyrocare_0_4618.xml',
#  './datasets/images/thyrocare_0_4670.xml',
#  './datasets/images/thyrocare_0_4683.xml',
#  './datasets/images/thyrocare_0_4790.xml',
#  './datasets/images/thyrocare_0_4979.xml',
#  './datasets/images/thyrocare_0_5074.xml',
#  './datasets/images/thyrocare_0_511.xml',
#  './datasets/images/thyrocare_0_517.xml',
#  './datasets/images/thyrocare_0_5338.xml',
#  './datasets/images/thyrocare_0_5640.xml',
#  './datasets/images/thyrocare_0_5816.xml',
#  './datasets/images/thyrocare_0_5858.xml',
#  './datasets/images/thyrocare_0_5879.xml',
#  './datasets/images/thyrocare_0_657.xml',
#  './datasets/images/thyrocare_0_6716.xml',
#  './datasets/images/thyrocare_0_6723.xml',
#  './datasets/images/thyrocare_0_6743.xml',
#  './datasets/images/thyrocare_0_6884.xml',
#  './datasets/images/thyrocare_0_7075.xml',
#  './datasets/images/thyrocare_0_7082.xml',
#  './datasets/images/thyrocare_0_7109.xml',
#  './datasets/images/thyrocare_0_7219.xml',
#  './datasets/images/thyrocare_0_757.xml',
#  './datasets/images/thyrocare_0_7571.xml',
#  './datasets/images/thyrocare_0_7601.xml',
#  './datasets/images/thyrocare_0_7635.xml',
#  './datasets/images/thyrocare_0_7758.xml',
#  './datasets/images/thyrocare_0_7805.xml',
#  './datasets/images/thyrocare_0_8214.xml',
#  './datasets/images/thyrocare_0_8251.xml',
#  './datasets/images/thyrocare_0_8302.xml',
#  './datasets/images/thyrocare_0_8394.xml',
#  './datasets/images/thyrocare_0_8748.xml',
#  './datasets/images/thyrocare_0_8749.xml',
#  './datasets/images/thyrocare_0_9047.xml',
#  './datasets/images/thyrocare_0_912.xml',
#  './datasets/images/thyrocare_0_9207.xml',
#  './datasets/images/thyrocare_0_9447.xml',
#  './datasets/images/thyrocare_0_9575.xml',
#  './datasets/images/thyrocare_0_9691.xml']

# %%
# Function to extract relevant information from each XML annotation file
def extract_text(filename):
    tree = et.parse(filename)  # Parse the XML file
    root = tree.getroot()       # Get the root of the XML tree

    # Extract the filename of the image
    image_name = root.find('filename').text

    # Extract the size (width and height) of the image
    width = root.find('size').find('width').text
    height = root.find('size').find('height').text

    # Extract all object annotations (bounding boxes)
    objects = root.findall('object')
    parser = []

    # Iterate through each object (annotation) and extract relevant details
    for object in objects:
        name = object.find('name').text                # Object class (e.g., Test Name, Value)
        bndbox = object.find('bndbox')                 # Bounding box coordinates
        xmin = bndbox.find('xmin').text                # Left boundary of the object
        xmax = bndbox.find('xmax').text                # Right boundary of the object
        ymin = bndbox.find('ymin').text                # Top boundary of the object
        ymax = bndbox.find('ymax').text                # Bottom boundary of the object
        
        # Append extracted data as a list for this object
        parser.append([image_name, width, height, name, xmin, xmax, ymin, ymax])

    return parser  # Return the list of extracted objects from this file

# %%
# Apply extract_text to all XML files and store results in parser_all
parser_all = list(map(extract_text, xml_files))

# %%
parser_all
# Out:
# [[['thyrocare_0_122.jpg', '939', '631', 'Test Name', '1', '329', '399', '463'],
#   ['thyrocare_0_122.jpg', '939', '631', 'Value', '503', '554', '394', '453'],
#   ['thyrocare_0_122.jpg', '939', '631', 'Units', '607', '671', '392', '450'],
#   ['thyrocare_0_122.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '672',
#    '736',
#    '392',
#    '450']],
#  [['thyrocare_0_1374.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '51',
#    '420',
#    '346',
#    '595'],
#   ['thyrocare_0_1374.jpg', '1068', '635', 'Value', '682', '744', '347', '590'],
#   ['thyrocare_0_1374.jpg', '1068', '635', 'Units', '805', '873', '348', '589'],
#   ['thyrocare_0_1374.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '908',
#    '991',
#    '348',
#    '588']],
#  [['thyrocare_0_1433.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '82',
#    '355',
#    '407',
#    '480'],
#   ['thyrocare_0_1433.jpg', '939', '631', 'Value', '495', '542', '400', '469'],
#   ['thyrocare_0_1433.jpg', '939', '631', 'Units', '583', '634', '398', '466'],
#   ['thyrocare_0_1433.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '634',
#    '690',
#    '399',
#    '463']],
#  [['thyrocare_0_1861.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '66',
#    '423',
#    '350',
#    '616'],
#   ['thyrocare_0_1861.jpg', '1068', '635', 'Value', '677', '741', '349', '607'],
#   ['thyrocare_0_1861.jpg', '1068', '635', 'Units', '792', '865', '349', '607'],
#   ['thyrocare_0_1861.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '898',
#    '976',
#    '349',
#    '605']],
#  [['thyrocare_0_2177.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '3',
#    '333',
#    '411',
#    '484'],
#   ['thyrocare_0_2177.jpg', '939', '631', 'Value', '504', '553', '403', '472'],
#   ['thyrocare_0_2177.jpg', '939', '631', 'Units', '606', '667', '401', '471'],
#   ['thyrocare_0_2177.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '667',
#    '734',
#    '401',
#    '470']],
#  [['thyrocare_0_2300.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '93',
#    '431',
#    '348',
#    '606'],
#   ['thyrocare_0_2300.jpg', '1068', '635', 'Value', '672', '727', '347', '599'],
#   ['thyrocare_0_2300.jpg', '1068', '635', 'Units', '779', '850', '348', '598'],
#   ['thyrocare_0_2300.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '877',
#    '955',
#    '349',
#    '596']],
#  [['thyrocare_0_2505.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '34',
#    '338',
#    '417',
#    '494'],
#   ['thyrocare_0_2505.jpg', '939', '631', 'Value', '499', '548', '408', '479'],
#   ['thyrocare_0_2505.jpg', '939', '631', 'Units', '599', '656', '406', '478'],
#   ['thyrocare_0_2505.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '655',
#    '719',
#    '405',
#    '477']],
#  [['thyrocare_0_2649.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '97',
#    '431',
#    '343',
#    '570'],
#   ['thyrocare_0_2649.jpg', '1068', '635', 'Value', '671', '727', '343', '561'],
#   ['thyrocare_0_2649.jpg', '1068', '635', 'Units', '776', '845', '343', '561'],
#   ['thyrocare_0_2649.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '868',
#    '951',
#    '343',
#    '560']],
#  [['thyrocare_0_2737.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '151',
#    '449',
#    '347',
#    '614'],
#   ['thyrocare_0_2737.jpg', '1068', '635', 'Value', '650', '702', '348', '608'],
#   ['thyrocare_0_2737.jpg', '1068', '635', 'Units', '742', '809', '348', '607'],
#   ['thyrocare_0_2737.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '823',
#    '897',
#    '349',
#    '605']],
#  [['thyrocare_0_2841.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '88',
#    '429',
#    '339',
#    '556'],
#   ['thyrocare_0_2841.jpg', '1068', '635', 'Value', '671', '725', '342', '551'],
#   ['thyrocare_0_2841.jpg', '1068', '635', 'Units', '778', '848', '342', '550'],
#   ['thyrocare_0_2841.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '876',
#    '952',
#    '343',
#    '550']],
#  [['thyrocare_0_2866.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '37',
#    '343',
#    '401',
#    '469'],
#   ['thyrocare_0_2866.jpg', '939', '631', 'Value', '500', '545', '394', '457'],
#   ['thyrocare_0_2866.jpg', '939', '631', 'Units', '594', '652', '393', '455'],
#   ['thyrocare_0_2866.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '652',
#    '715',
#    '391',
#    '456']],
#  [['thyrocare_0_2885.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '41',
#    '343',
#    '391',
#    '454'],
#   ['thyrocare_0_2885.jpg', '939', '631', 'Value', '501', '544', '386', '444'],
#   ['thyrocare_0_2885.jpg', '939', '631', 'Units', '597', '651', '384', '444'],
#   ['thyrocare_0_2885.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '652',
#    '715',
#    '384',
#    '442']],
#  [['thyrocare_0_3439.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '68',
#    '351',
#    '399',
#    '464'],
#   ['thyrocare_0_3439.jpg', '939', '631', 'Value', '497', '543', '392', '454'],
#   ['thyrocare_0_3439.jpg', '939', '631', 'Units', '587', '641', '390', '454'],
#   ['thyrocare_0_3439.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '641',
#    '699',
#    '389',
#    '450']],
#  [['thyrocare_0_3558.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '101',
#    '434',
#    '341',
#    '546'],
#   ['thyrocare_0_3558.jpg', '1068', '635', 'Value', '666', '724', '340', '539'],
#   ['thyrocare_0_3558.jpg', '1068', '635', 'Units', '771', '838', '340', '538'],
#   ['thyrocare_0_3558.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '865',
#    '941',
#    '340',
#    '537']],
#  [['thyrocare_0_3804.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '34',
#    '343',
#    '410',
#    '482'],
#   ['thyrocare_0_3804.jpg', '939', '631', 'Value', '499', '545', '401', '470'],
#   ['thyrocare_0_3804.jpg', '939', '631', 'Units', '597', '657', '399', '468'],
#   ['thyrocare_0_3804.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '656',
#    '717',
#    '398',
#    '467']],
#  [['thyrocare_0_3813.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '50',
#    '421',
#    '349',
#    '617'],
#   ['thyrocare_0_3813.jpg', '1068', '635', 'Value', '681', '745', '349', '608'],
#   ['thyrocare_0_3813.jpg', '1068', '635', 'Units', '801', '874', '349', '606'],
#   ['thyrocare_0_3813.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '905',
#    '987',
#    '349',
#    '604']],
#  [['thyrocare_0_421.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '68',
#    '421',
#    '342',
#    '559'],
#   ['thyrocare_0_421.jpg', '1068', '635', 'Value', '676', '736', '343', '554'],
#   ['thyrocare_0_421.jpg', '1068', '635', 'Units', '792', '855', '344', '554'],
#   ['thyrocare_0_421.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '893',
#    '976',
#    '345',
#    '552']],
#  [['thyrocare_0_4468.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '70',
#    '355',
#    '426',
#    '513'],
#   ['thyrocare_0_4468.jpg', '939', '631', 'Value', '496', '541', '418', '501'],
#   ['thyrocare_0_4468.jpg', '939', '631', 'Units', '585', '641', '416', '497'],
#   ['thyrocare_0_4468.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '640',
#    '698',
#    '414',
#    '495']],
#  [['thyrocare_0_447.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '87',
#    '355',
#    '394',
#    '456'],
#   ['thyrocare_0_447.jpg', '939', '631', 'Value', '493', '542', '387', '444'],
#   ['thyrocare_0_447.jpg', '939', '631', 'Units', '580', '633', '385', '441'],
#   ['thyrocare_0_447.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '632',
#    '685',
#    '384',
#    '443']],
#  [['thyrocare_0_4618.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '77',
#    '352',
#    '395',
#    '461'],
#   ['thyrocare_0_4618.jpg', '939', '631', 'Value', '494', '541', '389', '448'],
#   ['thyrocare_0_4618.jpg', '939', '631', 'Units', '584', '636', '387', '448'],
#   ['thyrocare_0_4618.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '636',
#    '695',
#    '386',
#    '445']],
#  [['thyrocare_0_4670.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '27',
#    '338',
#    '415',
#    '494'],
#   ['thyrocare_0_4670.jpg', '939', '631', 'Value', '499', '555', '407', '480'],
#   ['thyrocare_0_4670.jpg', '939', '631', 'Units', '598', '659', '404', '477'],
#   ['thyrocare_0_4670.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '659',
#    '722',
#    '404',
#    '475']],
#  [['thyrocare_0_4683.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '49',
#    '345',
#    '391',
#    '454'],
#   ['thyrocare_0_4683.jpg', '939', '631', 'Value', '497', '548', '385', '444'],
#   ['thyrocare_0_4683.jpg', '939', '631', 'Units', '591', '650', '385', '441'],
#   ['thyrocare_0_4683.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '651',
#    '709',
#    '385',
#    '442']],
#  [['thyrocare_0_4790.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '98',
#    '359',
#    '391',
#    '455'],
#   ['thyrocare_0_4790.jpg', '939', '631', 'Value', '494', '542', '387', '445'],
#   ['thyrocare_0_4790.jpg', '939', '631', 'Units', '578', '629', '385', '442'],
#   ['thyrocare_0_4790.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '629',
#    '688',
#    '386',
#    '443']],
#  [['thyrocare_0_4979.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '145',
#    '444',
#    '351',
#    '625'],
#   ['thyrocare_0_4979.jpg', '1068', '635', 'Value', '651', '709', '350', '617'],
#   ['thyrocare_0_4979.jpg', '1068', '635', 'Units', '747', '814', '351', '616'],
#   ['thyrocare_0_4979.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '831',
#    '910',
#    '352',
#    '614']],
#  [['thyrocare_0_5074.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '61',
#    '350',
#    '396',
#    '458'],
#   ['thyrocare_0_5074.jpg', '939', '631', 'Value', '496', '543', '388', '450'],
#   ['thyrocare_0_5074.jpg', '939', '631', 'Units', '588', '644', '387', '448'],
#   ['thyrocare_0_5074.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '643',
#    '703',
#    '386',
#    '447']],
#  [['thyrocare_0_511.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '104',
#    '363',
#    '421',
#    '498'],
#   ['thyrocare_0_511.jpg', '939', '631', 'Value', '494', '538', '413', '485'],
#   ['thyrocare_0_511.jpg', '939', '631', 'Units', '574', '624', '410', '485'],
#   ['thyrocare_0_511.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '623',
#    '674',
#    '409',
#    '482']],
#  [['thyrocare_0_517.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '62',
#    '350',
#    '400',
#    '462'],
#   ['thyrocare_0_517.jpg', '939', '631', 'Value', '497', '545', '393', '451'],
#   ['thyrocare_0_517.jpg', '939', '631', 'Units', '587', '644', '389', '451'],
#   ['thyrocare_0_517.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '641',
#    '701',
#    '389',
#    '450']],
#  [['thyrocare_0_5338.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '79',
#    '356',
#    '407',
#    '479'],
#   ['thyrocare_0_5338.jpg', '939', '631', 'Value', '496', '541', '400', '467'],
#   ['thyrocare_0_5338.jpg', '939', '631', 'Units', '583', '636', '398', '467'],
#   ['thyrocare_0_5338.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '635',
#    '694',
#    '397',
#    '465']],
#  [['thyrocare_0_5640.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '124',
#    '437',
#    '341',
#    '545'],
#   ['thyrocare_0_5640.jpg', '1068', '635', 'Value', '656', '720', '340', '538'],
#   ['thyrocare_0_5640.jpg', '1068', '635', 'Units', '756', '831', '340', '536'],
#   ['thyrocare_0_5640.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '851',
#    '929',
#    '339',
#    '537']],
#  [['thyrocare_0_5816.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '34',
#    '418',
#    '352',
#    '635'],
#   ['thyrocare_0_5816.jpg', '1068', '635', 'Value', '690', '757', '351', '628'],
#   ['thyrocare_0_5816.jpg', '1068', '635', 'Units', '811', '892', '351', '627'],
#   ['thyrocare_0_5816.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '921',
#    '1016',
#    '351',
#    '625']],
#  [['thyrocare_0_5858.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '72',
#    '427',
#    '349',
#    '623'],
#   ['thyrocare_0_5858.jpg', '1068', '635', 'Value', '674', '744', '349', '611'],
#   ['thyrocare_0_5858.jpg', '1068', '635', 'Units', '788', '866', '349', '613'],
#   ['thyrocare_0_5858.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '891',
#    '973',
#    '350',
#    '612']],
#  [['thyrocare_0_5879.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '12',
#    '337',
#    '401',
#    '470'],
#   ['thyrocare_0_5879.jpg', '939', '631', 'Value', '501', '554', '393', '460'],
#   ['thyrocare_0_5879.jpg', '939', '631', 'Units', '602', '665', '392', '457'],
#   ['thyrocare_0_5879.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '665',
#    '732',
#    '392',
#    '456']],
#  [['thyrocare_0_657.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '109',
#    '439',
#    '348',
#    '614'],
#   ['thyrocare_0_657.jpg', '1068', '635', 'Value', '664', '718', '348', '606'],
#   ['thyrocare_0_657.jpg', '1068', '635', 'Units', '768', '838', '348', '606'],
#   ['thyrocare_0_657.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '862',
#    '934',
#    '351',
#    '605']],
#  [['thyrocare_0_6716.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '67',
#    '354',
#    '398',
#    '463'],
#   ['thyrocare_0_6716.jpg', '939', '631', 'Value', '496', '543', '390', '452'],
#   ['thyrocare_0_6716.jpg', '939', '631', 'Units', '586', '644', '389', '451'],
#   ['thyrocare_0_6716.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '642',
#    '701',
#    '388',
#    '452']],
#  [['thyrocare_0_6723.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '39',
#    '349',
#    '421',
#    '502'],
#   ['thyrocare_0_6723.jpg', '939', '631', 'Value', '501', '547', '413', '489'],
#   ['thyrocare_0_6723.jpg', '939', '631', 'Units', '594', '653', '411', '486'],
#   ['thyrocare_0_6723.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '652',
#    '717',
#    '409',
#    '487']],
#  [['thyrocare_0_6743.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '92',
#    '363',
#    '408',
#    '483'],
#   ['thyrocare_0_6743.jpg', '939', '631', 'Value', '495', '540', '401', '472'],
#   ['thyrocare_0_6743.jpg', '939', '631', 'Units', '578', '633', '399', '469'],
#   ['thyrocare_0_6743.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '631',
#    '690',
#    '399',
#    '469']],
#  [['thyrocare_0_6884.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '32',
#    '340',
#    '416',
#    '496'],
#   ['thyrocare_0_6884.jpg', '939', '631', 'Value', '499', '550', '408', '484'],
#   ['thyrocare_0_6884.jpg', '939', '631', 'Units', '594', '657', '406', '481'],
#   ['thyrocare_0_6884.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '656',
#    '719',
#    '405',
#    '481']],
#  [['thyrocare_0_7075.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '114',
#    '367',
#    '400',
#    '464'],
#   ['thyrocare_0_7075.jpg', '939', '631', 'Value', '492', '536', '391', '455'],
#   ['thyrocare_0_7075.jpg', '939', '631', 'Units', '572', '622', '390', '452'],
#   ['thyrocare_0_7075.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '621',
#    '677',
#    '388',
#    '452']],
#  [['thyrocare_0_7082.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '82',
#    '358',
#    '415',
#    '491'],
#   ['thyrocare_0_7082.jpg', '939', '631', 'Value', '495', '542', '406', '481'],
#   ['thyrocare_0_7082.jpg', '939', '631', 'Units', '581', '637', '404', '480'],
#   ['thyrocare_0_7082.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '635',
#    '691',
#    '403',
#    '478']],
#  [['thyrocare_0_7109.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '45',
#    '425',
#    '345',
#    '580'],
#   ['thyrocare_0_7109.jpg', '1068', '635', 'Value', '682', '747', '343', '571'],
#   ['thyrocare_0_7109.jpg', '1068', '635', 'Units', '801', '880', '343', '571'],
#   ['thyrocare_0_7109.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '909',
#    '993',
#    '343',
#    '571']],
#  [['thyrocare_0_7219.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '21',
#    '340',
#    '414',
#    '491'],
#   ['thyrocare_0_7219.jpg', '939', '631', 'Value', '501', '553', '406', '481'],
#   ['thyrocare_0_7219.jpg', '939', '631', 'Units', '599', '663', '404', '479'],
#   ['thyrocare_0_7219.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '661',
#    '728',
#    '404',
#    '476']],
#  [['thyrocare_0_757.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '114',
#    '365',
#    '410',
#    '484'],
#   ['thyrocare_0_757.jpg', '939', '631', 'Value', '492', '534', '402', '469'],
#   ['thyrocare_0_757.jpg', '939', '631', 'Units', '570', '622', '399', '468'],
#   ['thyrocare_0_757.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '620',
#    '673',
#    '400',
#    '467']],
#  [['thyrocare_0_7571.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '74',
#    '355',
#    '413',
#    '492'],
#   ['thyrocare_0_7571.jpg', '939', '631', 'Value', '495', '542', '404', '480'],
#   ['thyrocare_0_7571.jpg', '939', '631', 'Units', '583', '639', '404', '476'],
#   ['thyrocare_0_7571.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '636',
#    '695',
#    '401',
#    '475']],
#  [['thyrocare_0_7601.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '1',
#    '331',
#    '396',
#    '462'],
#   ['thyrocare_0_7601.jpg', '939', '631', 'Value', '502', '554', '390', '452'],
#   ['thyrocare_0_7601.jpg', '939', '631', 'Units', '606', '670', '388', '450'],
#   ['thyrocare_0_7601.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '668',
#    '739',
#    '386',
#    '449']],
#  [['thyrocare_0_7635.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '87',
#    '433',
#    '345',
#    '587'],
#   ['thyrocare_0_7635.jpg', '1068', '635', 'Value', '671', '731', '349', '580'],
#   ['thyrocare_0_7635.jpg', '1068', '635', 'Units', '780', '853', '346', '579'],
#   ['thyrocare_0_7635.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '877',
#    '967',
#    '346',
#    '577']],
#  [['thyrocare_0_7758.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '89',
#    '360',
#    '402',
#    '472'],
#   ['thyrocare_0_7758.jpg', '939', '631', 'Value', '495', '540', '395', '461'],
#   ['thyrocare_0_7758.jpg', '939', '631', 'Units', '579', '633', '393', '460'],
#   ['thyrocare_0_7758.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '631',
#    '690',
#    '392',
#    '459']],
#  [['thyrocare_0_7805.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '113',
#    '369',
#    '406',
#    '478'],
#   ['thyrocare_0_7805.jpg', '939', '631', 'Value', '490', '539', '399', '468'],
#   ['thyrocare_0_7805.jpg', '939', '631', 'Units', '573', '621', '397', '466'],
#   ['thyrocare_0_7805.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '619',
#    '676',
#    '397',
#    '465']],
#  [['thyrocare_0_8214.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '35',
#    '346',
#    '391',
#    '452'],
#   ['thyrocare_0_8214.jpg', '939', '631', 'Value', '498', '550', '385', '444'],
#   ['thyrocare_0_8214.jpg', '939', '631', 'Units', '595', '653', '384', '443'],
#   ['thyrocare_0_8214.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '651',
#    '717',
#    '382',
#    '440']],
#  [['thyrocare_0_8251.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '79',
#    '434',
#    '345',
#    '583'],
#   ['thyrocare_0_8251.jpg', '1068', '635', 'Value', '668', '737', '345', '576'],
#   ['thyrocare_0_8251.jpg', '1068', '635', 'Units', '784', '859', '346', '575'],
#   ['thyrocare_0_8251.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '882',
#    '967',
#    '345',
#    '574']],
#  [['thyrocare_0_8302.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '84',
#    '433',
#    '350',
#    '631'],
#   ['thyrocare_0_8302.jpg', '1068', '635', 'Value', '669', '736', '349', '622'],
#   ['thyrocare_0_8302.jpg', '1068', '635', 'Units', '782', '857', '350', '620'],
#   ['thyrocare_0_8302.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '878',
#    '965',
#    '350',
#    '620']],
#  [['thyrocare_0_8394.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '42',
#    '347',
#    '403',
#    '473'],
#   ['thyrocare_0_8394.jpg', '939', '631', 'Value', '498', '549', '395', '463'],
#   ['thyrocare_0_8394.jpg', '939', '631', 'Units', '593', '653', '393', '461'],
#   ['thyrocare_0_8394.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '652',
#    '715',
#    '392',
#    '458']],
#  [['thyrocare_0_8748.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '27',
#    '342',
#    '393',
#    '457'],
#   ['thyrocare_0_8748.jpg', '939', '631', 'Value', '500', '553', '387', '447'],
#   ['thyrocare_0_8748.jpg', '939', '631', 'Units', '598', '660', '385', '446'],
#   ['thyrocare_0_8748.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '658',
#    '724',
#    '384',
#    '446']],
#  [['thyrocare_0_8749.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '96',
#    '361',
#    '397',
#    '464'],
#   ['thyrocare_0_8749.jpg', '939', '631', 'Value', '496', '537', '390', '453'],
#   ['thyrocare_0_8749.jpg', '939', '631', 'Units', '577', '629', '388', '451'],
#   ['thyrocare_0_8749.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '627',
#    '683',
#    '387',
#    '451']],
#  [['thyrocare_0_9047.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '39',
#    '421',
#    '343',
#    '563'],
#   ['thyrocare_0_9047.jpg', '1068', '635', 'Value', '687', '752', '342', '556'],
#   ['thyrocare_0_9047.jpg', '1068', '635', 'Units', '808', '887', '342', '556'],
#   ['thyrocare_0_9047.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '918',
#    '1002',
#    '345',
#    '557']],
#  [['thyrocare_0_912.jpg', '939', '631', 'Test Name', '9', '333', '397', '461'],
#   ['thyrocare_0_912.jpg', '939', '631', 'Value', '503', '552', '390', '448'],
#   ['thyrocare_0_912.jpg', '939', '631', 'Units', '606', '667', '389', '449'],
#   ['thyrocare_0_912.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '667',
#    '730',
#    '390',
#    '446']],
#  [['thyrocare_0_9207.jpg',
#    '1068',
#    '635',
#    'Test Name',
#    '21',
#    '415',
#    '342',
#    '564'],
#   ['thyrocare_0_9207.jpg', '1068', '635', 'Value', '690', '758', '342', '556'],
#   ['thyrocare_0_9207.jpg', '1068', '635', 'Units', '819', '897', '343', '553'],
#   ['thyrocare_0_9207.jpg',
#    '1068',
#    '635',
#    'Reference Range',
#    '929',
#    '1024',
#    '343',
#    '553']],
#  [['thyrocare_0_9447.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '105',
#    '367',
#    '426',
#    '509'],
#   ['thyrocare_0_9447.jpg', '939', '631', 'Value', '490', '539', '415', '498'],
#   ['thyrocare_0_9447.jpg', '939', '631', 'Units', '575', '627', '412', '494'],
#   ['thyrocare_0_9447.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '625',
#    '682',
#    '411',
#    '495']],
#  [['thyrocare_0_9575.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '76',
#    '357',
#    '408',
#    '481'],
#   ['thyrocare_0_9575.jpg', '939', '631', 'Value', '495', '540', '401', '472'],
#   ['thyrocare_0_9575.jpg', '939', '631', 'Units', '582', '637', '397', '469'],
#   ['thyrocare_0_9575.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '635',
#    '694',
#    '397',
#    '468']],
#  [['thyrocare_0_9691.jpg',
#    '939',
#    '631',
#    'Test Name',
#    '49',
#    '349',
#    '422',
#    '502'],
#   ['thyrocare_0_9691.jpg', '939', '631', 'Value', '497', '547', '411', '490'],
#   ['thyrocare_0_9691.jpg', '939', '631', 'Units', '591', '648', '410', '488'],
#   ['thyrocare_0_9691.jpg',
#    '939',
#    '631',
#    'Reference Range',
#    '649',
#    '709',
#    '409',
#    '486']]]

# %%
# Flatten the list of lists into a single list
data = reduce(lambda x, y : x + y, parser_all)

# %%
data
# Out:
# [['thyrocare_0_122.jpg', '939', '631', 'Test Name', '1', '329', '399', '463'],
#  ['thyrocare_0_122.jpg', '939', '631', 'Value', '503', '554', '394', '453'],
#  ['thyrocare_0_122.jpg', '939', '631', 'Units', '607', '671', '392', '450'],
#  ['thyrocare_0_122.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '672',
#   '736',
#   '392',
#   '450'],
#  ['thyrocare_0_1374.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '51',
#   '420',
#   '346',
#   '595'],
#  ['thyrocare_0_1374.jpg', '1068', '635', 'Value', '682', '744', '347', '590'],
#  ['thyrocare_0_1374.jpg', '1068', '635', 'Units', '805', '873', '348', '589'],
#  ['thyrocare_0_1374.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '908',
#   '991',
#   '348',
#   '588'],
#  ['thyrocare_0_1433.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '82',
#   '355',
#   '407',
#   '480'],
#  ['thyrocare_0_1433.jpg', '939', '631', 'Value', '495', '542', '400', '469'],
#  ['thyrocare_0_1433.jpg', '939', '631', 'Units', '583', '634', '398', '466'],
#  ['thyrocare_0_1433.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '634',
#   '690',
#   '399',
#   '463'],
#  ['thyrocare_0_1861.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '66',
#   '423',
#   '350',
#   '616'],
#  ['thyrocare_0_1861.jpg', '1068', '635', 'Value', '677', '741', '349', '607'],
#  ['thyrocare_0_1861.jpg', '1068', '635', 'Units', '792', '865', '349', '607'],
#  ['thyrocare_0_1861.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '898',
#   '976',
#   '349',
#   '605'],
#  ['thyrocare_0_2177.jpg', '939', '631', 'Test Name', '3', '333', '411', '484'],
#  ['thyrocare_0_2177.jpg', '939', '631', 'Value', '504', '553', '403', '472'],
#  ['thyrocare_0_2177.jpg', '939', '631', 'Units', '606', '667', '401', '471'],
#  ['thyrocare_0_2177.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '667',
#   '734',
#   '401',
#   '470'],
#  ['thyrocare_0_2300.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '93',
#   '431',
#   '348',
#   '606'],
#  ['thyrocare_0_2300.jpg', '1068', '635', 'Value', '672', '727', '347', '599'],
#  ['thyrocare_0_2300.jpg', '1068', '635', 'Units', '779', '850', '348', '598'],
#  ['thyrocare_0_2300.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '877',
#   '955',
#   '349',
#   '596'],
#  ['thyrocare_0_2505.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '34',
#   '338',
#   '417',
#   '494'],
#  ['thyrocare_0_2505.jpg', '939', '631', 'Value', '499', '548', '408', '479'],
#  ['thyrocare_0_2505.jpg', '939', '631', 'Units', '599', '656', '406', '478'],
#  ['thyrocare_0_2505.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '655',
#   '719',
#   '405',
#   '477'],
#  ['thyrocare_0_2649.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '97',
#   '431',
#   '343',
#   '570'],
#  ['thyrocare_0_2649.jpg', '1068', '635', 'Value', '671', '727', '343', '561'],
#  ['thyrocare_0_2649.jpg', '1068', '635', 'Units', '776', '845', '343', '561'],
#  ['thyrocare_0_2649.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '868',
#   '951',
#   '343',
#   '560'],
#  ['thyrocare_0_2737.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '151',
#   '449',
#   '347',
#   '614'],
#  ['thyrocare_0_2737.jpg', '1068', '635', 'Value', '650', '702', '348', '608'],
#  ['thyrocare_0_2737.jpg', '1068', '635', 'Units', '742', '809', '348', '607'],
#  ['thyrocare_0_2737.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '823',
#   '897',
#   '349',
#   '605'],
#  ['thyrocare_0_2841.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '88',
#   '429',
#   '339',
#   '556'],
#  ['thyrocare_0_2841.jpg', '1068', '635', 'Value', '671', '725', '342', '551'],
#  ['thyrocare_0_2841.jpg', '1068', '635', 'Units', '778', '848', '342', '550'],
#  ['thyrocare_0_2841.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '876',
#   '952',
#   '343',
#   '550'],
#  ['thyrocare_0_2866.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '37',
#   '343',
#   '401',
#   '469'],
#  ['thyrocare_0_2866.jpg', '939', '631', 'Value', '500', '545', '394', '457'],
#  ['thyrocare_0_2866.jpg', '939', '631', 'Units', '594', '652', '393', '455'],
#  ['thyrocare_0_2866.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '652',
#   '715',
#   '391',
#   '456'],
#  ['thyrocare_0_2885.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '41',
#   '343',
#   '391',
#   '454'],
#  ['thyrocare_0_2885.jpg', '939', '631', 'Value', '501', '544', '386', '444'],
#  ['thyrocare_0_2885.jpg', '939', '631', 'Units', '597', '651', '384', '444'],
#  ['thyrocare_0_2885.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '652',
#   '715',
#   '384',
#   '442'],
#  ['thyrocare_0_3439.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '68',
#   '351',
#   '399',
#   '464'],
#  ['thyrocare_0_3439.jpg', '939', '631', 'Value', '497', '543', '392', '454'],
#  ['thyrocare_0_3439.jpg', '939', '631', 'Units', '587', '641', '390', '454'],
#  ['thyrocare_0_3439.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '641',
#   '699',
#   '389',
#   '450'],
#  ['thyrocare_0_3558.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '101',
#   '434',
#   '341',
#   '546'],
#  ['thyrocare_0_3558.jpg', '1068', '635', 'Value', '666', '724', '340', '539'],
#  ['thyrocare_0_3558.jpg', '1068', '635', 'Units', '771', '838', '340', '538'],
#  ['thyrocare_0_3558.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '865',
#   '941',
#   '340',
#   '537'],
#  ['thyrocare_0_3804.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '34',
#   '343',
#   '410',
#   '482'],
#  ['thyrocare_0_3804.jpg', '939', '631', 'Value', '499', '545', '401', '470'],
#  ['thyrocare_0_3804.jpg', '939', '631', 'Units', '597', '657', '399', '468'],
#  ['thyrocare_0_3804.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '656',
#   '717',
#   '398',
#   '467'],
#  ['thyrocare_0_3813.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '50',
#   '421',
#   '349',
#   '617'],
#  ['thyrocare_0_3813.jpg', '1068', '635', 'Value', '681', '745', '349', '608'],
#  ['thyrocare_0_3813.jpg', '1068', '635', 'Units', '801', '874', '349', '606'],
#  ['thyrocare_0_3813.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '905',
#   '987',
#   '349',
#   '604'],
#  ['thyrocare_0_421.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '68',
#   '421',
#   '342',
#   '559'],
#  ['thyrocare_0_421.jpg', '1068', '635', 'Value', '676', '736', '343', '554'],
#  ['thyrocare_0_421.jpg', '1068', '635', 'Units', '792', '855', '344', '554'],
#  ['thyrocare_0_421.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '893',
#   '976',
#   '345',
#   '552'],
#  ['thyrocare_0_4468.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '70',
#   '355',
#   '426',
#   '513'],
#  ['thyrocare_0_4468.jpg', '939', '631', 'Value', '496', '541', '418', '501'],
#  ['thyrocare_0_4468.jpg', '939', '631', 'Units', '585', '641', '416', '497'],
#  ['thyrocare_0_4468.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '640',
#   '698',
#   '414',
#   '495'],
#  ['thyrocare_0_447.jpg', '939', '631', 'Test Name', '87', '355', '394', '456'],
#  ['thyrocare_0_447.jpg', '939', '631', 'Value', '493', '542', '387', '444'],
#  ['thyrocare_0_447.jpg', '939', '631', 'Units', '580', '633', '385', '441'],
#  ['thyrocare_0_447.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '632',
#   '685',
#   '384',
#   '443'],
#  ['thyrocare_0_4618.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '77',
#   '352',
#   '395',
#   '461'],
#  ['thyrocare_0_4618.jpg', '939', '631', 'Value', '494', '541', '389', '448'],
#  ['thyrocare_0_4618.jpg', '939', '631', 'Units', '584', '636', '387', '448'],
#  ['thyrocare_0_4618.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '636',
#   '695',
#   '386',
#   '445'],
#  ['thyrocare_0_4670.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '27',
#   '338',
#   '415',
#   '494'],
#  ['thyrocare_0_4670.jpg', '939', '631', 'Value', '499', '555', '407', '480'],
#  ['thyrocare_0_4670.jpg', '939', '631', 'Units', '598', '659', '404', '477'],
#  ['thyrocare_0_4670.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '659',
#   '722',
#   '404',
#   '475'],
#  ['thyrocare_0_4683.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '49',
#   '345',
#   '391',
#   '454'],
#  ['thyrocare_0_4683.jpg', '939', '631', 'Value', '497', '548', '385', '444'],
#  ['thyrocare_0_4683.jpg', '939', '631', 'Units', '591', '650', '385', '441'],
#  ['thyrocare_0_4683.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '651',
#   '709',
#   '385',
#   '442'],
#  ['thyrocare_0_4790.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '98',
#   '359',
#   '391',
#   '455'],
#  ['thyrocare_0_4790.jpg', '939', '631', 'Value', '494', '542', '387', '445'],
#  ['thyrocare_0_4790.jpg', '939', '631', 'Units', '578', '629', '385', '442'],
#  ['thyrocare_0_4790.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '629',
#   '688',
#   '386',
#   '443'],
#  ['thyrocare_0_4979.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '145',
#   '444',
#   '351',
#   '625'],
#  ['thyrocare_0_4979.jpg', '1068', '635', 'Value', '651', '709', '350', '617'],
#  ['thyrocare_0_4979.jpg', '1068', '635', 'Units', '747', '814', '351', '616'],
#  ['thyrocare_0_4979.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '831',
#   '910',
#   '352',
#   '614'],
#  ['thyrocare_0_5074.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '61',
#   '350',
#   '396',
#   '458'],
#  ['thyrocare_0_5074.jpg', '939', '631', 'Value', '496', '543', '388', '450'],
#  ['thyrocare_0_5074.jpg', '939', '631', 'Units', '588', '644', '387', '448'],
#  ['thyrocare_0_5074.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '643',
#   '703',
#   '386',
#   '447'],
#  ['thyrocare_0_511.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '104',
#   '363',
#   '421',
#   '498'],
#  ['thyrocare_0_511.jpg', '939', '631', 'Value', '494', '538', '413', '485'],
#  ['thyrocare_0_511.jpg', '939', '631', 'Units', '574', '624', '410', '485'],
#  ['thyrocare_0_511.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '623',
#   '674',
#   '409',
#   '482'],
#  ['thyrocare_0_517.jpg', '939', '631', 'Test Name', '62', '350', '400', '462'],
#  ['thyrocare_0_517.jpg', '939', '631', 'Value', '497', '545', '393', '451'],
#  ['thyrocare_0_517.jpg', '939', '631', 'Units', '587', '644', '389', '451'],
#  ['thyrocare_0_517.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '641',
#   '701',
#   '389',
#   '450'],
#  ['thyrocare_0_5338.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '79',
#   '356',
#   '407',
#   '479'],
#  ['thyrocare_0_5338.jpg', '939', '631', 'Value', '496', '541', '400', '467'],
#  ['thyrocare_0_5338.jpg', '939', '631', 'Units', '583', '636', '398', '467'],
#  ['thyrocare_0_5338.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '635',
#   '694',
#   '397',
#   '465'],
#  ['thyrocare_0_5640.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '124',
#   '437',
#   '341',
#   '545'],
#  ['thyrocare_0_5640.jpg', '1068', '635', 'Value', '656', '720', '340', '538'],
#  ['thyrocare_0_5640.jpg', '1068', '635', 'Units', '756', '831', '340', '536'],
#  ['thyrocare_0_5640.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '851',
#   '929',
#   '339',
#   '537'],
#  ['thyrocare_0_5816.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '34',
#   '418',
#   '352',
#   '635'],
#  ['thyrocare_0_5816.jpg', '1068', '635', 'Value', '690', '757', '351', '628'],
#  ['thyrocare_0_5816.jpg', '1068', '635', 'Units', '811', '892', '351', '627'],
#  ['thyrocare_0_5816.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '921',
#   '1016',
#   '351',
#   '625'],
#  ['thyrocare_0_5858.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '72',
#   '427',
#   '349',
#   '623'],
#  ['thyrocare_0_5858.jpg', '1068', '635', 'Value', '674', '744', '349', '611'],
#  ['thyrocare_0_5858.jpg', '1068', '635', 'Units', '788', '866', '349', '613'],
#  ['thyrocare_0_5858.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '891',
#   '973',
#   '350',
#   '612'],
#  ['thyrocare_0_5879.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '12',
#   '337',
#   '401',
#   '470'],
#  ['thyrocare_0_5879.jpg', '939', '631', 'Value', '501', '554', '393', '460'],
#  ['thyrocare_0_5879.jpg', '939', '631', 'Units', '602', '665', '392', '457'],
#  ['thyrocare_0_5879.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '665',
#   '732',
#   '392',
#   '456'],
#  ['thyrocare_0_657.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '109',
#   '439',
#   '348',
#   '614'],
#  ['thyrocare_0_657.jpg', '1068', '635', 'Value', '664', '718', '348', '606'],
#  ['thyrocare_0_657.jpg', '1068', '635', 'Units', '768', '838', '348', '606'],
#  ['thyrocare_0_657.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '862',
#   '934',
#   '351',
#   '605'],
#  ['thyrocare_0_6716.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '67',
#   '354',
#   '398',
#   '463'],
#  ['thyrocare_0_6716.jpg', '939', '631', 'Value', '496', '543', '390', '452'],
#  ['thyrocare_0_6716.jpg', '939', '631', 'Units', '586', '644', '389', '451'],
#  ['thyrocare_0_6716.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '642',
#   '701',
#   '388',
#   '452'],
#  ['thyrocare_0_6723.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '39',
#   '349',
#   '421',
#   '502'],
#  ['thyrocare_0_6723.jpg', '939', '631', 'Value', '501', '547', '413', '489'],
#  ['thyrocare_0_6723.jpg', '939', '631', 'Units', '594', '653', '411', '486'],
#  ['thyrocare_0_6723.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '652',
#   '717',
#   '409',
#   '487'],
#  ['thyrocare_0_6743.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '92',
#   '363',
#   '408',
#   '483'],
#  ['thyrocare_0_6743.jpg', '939', '631', 'Value', '495', '540', '401', '472'],
#  ['thyrocare_0_6743.jpg', '939', '631', 'Units', '578', '633', '399', '469'],
#  ['thyrocare_0_6743.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '631',
#   '690',
#   '399',
#   '469'],
#  ['thyrocare_0_6884.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '32',
#   '340',
#   '416',
#   '496'],
#  ['thyrocare_0_6884.jpg', '939', '631', 'Value', '499', '550', '408', '484'],
#  ['thyrocare_0_6884.jpg', '939', '631', 'Units', '594', '657', '406', '481'],
#  ['thyrocare_0_6884.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '656',
#   '719',
#   '405',
#   '481'],
#  ['thyrocare_0_7075.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '114',
#   '367',
#   '400',
#   '464'],
#  ['thyrocare_0_7075.jpg', '939', '631', 'Value', '492', '536', '391', '455'],
#  ['thyrocare_0_7075.jpg', '939', '631', 'Units', '572', '622', '390', '452'],
#  ['thyrocare_0_7075.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '621',
#   '677',
#   '388',
#   '452'],
#  ['thyrocare_0_7082.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '82',
#   '358',
#   '415',
#   '491'],
#  ['thyrocare_0_7082.jpg', '939', '631', 'Value', '495', '542', '406', '481'],
#  ['thyrocare_0_7082.jpg', '939', '631', 'Units', '581', '637', '404', '480'],
#  ['thyrocare_0_7082.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '635',
#   '691',
#   '403',
#   '478'],
#  ['thyrocare_0_7109.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '45',
#   '425',
#   '345',
#   '580'],
#  ['thyrocare_0_7109.jpg', '1068', '635', 'Value', '682', '747', '343', '571'],
#  ['thyrocare_0_7109.jpg', '1068', '635', 'Units', '801', '880', '343', '571'],
#  ['thyrocare_0_7109.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '909',
#   '993',
#   '343',
#   '571'],
#  ['thyrocare_0_7219.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '21',
#   '340',
#   '414',
#   '491'],
#  ['thyrocare_0_7219.jpg', '939', '631', 'Value', '501', '553', '406', '481'],
#  ['thyrocare_0_7219.jpg', '939', '631', 'Units', '599', '663', '404', '479'],
#  ['thyrocare_0_7219.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '661',
#   '728',
#   '404',
#   '476'],
#  ['thyrocare_0_757.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '114',
#   '365',
#   '410',
#   '484'],
#  ['thyrocare_0_757.jpg', '939', '631', 'Value', '492', '534', '402', '469'],
#  ['thyrocare_0_757.jpg', '939', '631', 'Units', '570', '622', '399', '468'],
#  ['thyrocare_0_757.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '620',
#   '673',
#   '400',
#   '467'],
#  ['thyrocare_0_7571.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '74',
#   '355',
#   '413',
#   '492'],
#  ['thyrocare_0_7571.jpg', '939', '631', 'Value', '495', '542', '404', '480'],
#  ['thyrocare_0_7571.jpg', '939', '631', 'Units', '583', '639', '404', '476'],
#  ['thyrocare_0_7571.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '636',
#   '695',
#   '401',
#   '475'],
#  ['thyrocare_0_7601.jpg', '939', '631', 'Test Name', '1', '331', '396', '462'],
#  ['thyrocare_0_7601.jpg', '939', '631', 'Value', '502', '554', '390', '452'],
#  ['thyrocare_0_7601.jpg', '939', '631', 'Units', '606', '670', '388', '450'],
#  ['thyrocare_0_7601.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '668',
#   '739',
#   '386',
#   '449'],
#  ['thyrocare_0_7635.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '87',
#   '433',
#   '345',
#   '587'],
#  ['thyrocare_0_7635.jpg', '1068', '635', 'Value', '671', '731', '349', '580'],
#  ['thyrocare_0_7635.jpg', '1068', '635', 'Units', '780', '853', '346', '579'],
#  ['thyrocare_0_7635.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '877',
#   '967',
#   '346',
#   '577'],
#  ['thyrocare_0_7758.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '89',
#   '360',
#   '402',
#   '472'],
#  ['thyrocare_0_7758.jpg', '939', '631', 'Value', '495', '540', '395', '461'],
#  ['thyrocare_0_7758.jpg', '939', '631', 'Units', '579', '633', '393', '460'],
#  ['thyrocare_0_7758.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '631',
#   '690',
#   '392',
#   '459'],
#  ['thyrocare_0_7805.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '113',
#   '369',
#   '406',
#   '478'],
#  ['thyrocare_0_7805.jpg', '939', '631', 'Value', '490', '539', '399', '468'],
#  ['thyrocare_0_7805.jpg', '939', '631', 'Units', '573', '621', '397', '466'],
#  ['thyrocare_0_7805.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '619',
#   '676',
#   '397',
#   '465'],
#  ['thyrocare_0_8214.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '35',
#   '346',
#   '391',
#   '452'],
#  ['thyrocare_0_8214.jpg', '939', '631', 'Value', '498', '550', '385', '444'],
#  ['thyrocare_0_8214.jpg', '939', '631', 'Units', '595', '653', '384', '443'],
#  ['thyrocare_0_8214.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '651',
#   '717',
#   '382',
#   '440'],
#  ['thyrocare_0_8251.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '79',
#   '434',
#   '345',
#   '583'],
#  ['thyrocare_0_8251.jpg', '1068', '635', 'Value', '668', '737', '345', '576'],
#  ['thyrocare_0_8251.jpg', '1068', '635', 'Units', '784', '859', '346', '575'],
#  ['thyrocare_0_8251.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '882',
#   '967',
#   '345',
#   '574'],
#  ['thyrocare_0_8302.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '84',
#   '433',
#   '350',
#   '631'],
#  ['thyrocare_0_8302.jpg', '1068', '635', 'Value', '669', '736', '349', '622'],
#  ['thyrocare_0_8302.jpg', '1068', '635', 'Units', '782', '857', '350', '620'],
#  ['thyrocare_0_8302.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '878',
#   '965',
#   '350',
#   '620'],
#  ['thyrocare_0_8394.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '42',
#   '347',
#   '403',
#   '473'],
#  ['thyrocare_0_8394.jpg', '939', '631', 'Value', '498', '549', '395', '463'],
#  ['thyrocare_0_8394.jpg', '939', '631', 'Units', '593', '653', '393', '461'],
#  ['thyrocare_0_8394.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '652',
#   '715',
#   '392',
#   '458'],
#  ['thyrocare_0_8748.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '27',
#   '342',
#   '393',
#   '457'],
#  ['thyrocare_0_8748.jpg', '939', '631', 'Value', '500', '553', '387', '447'],
#  ['thyrocare_0_8748.jpg', '939', '631', 'Units', '598', '660', '385', '446'],
#  ['thyrocare_0_8748.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '658',
#   '724',
#   '384',
#   '446'],
#  ['thyrocare_0_8749.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '96',
#   '361',
#   '397',
#   '464'],
#  ['thyrocare_0_8749.jpg', '939', '631', 'Value', '496', '537', '390', '453'],
#  ['thyrocare_0_8749.jpg', '939', '631', 'Units', '577', '629', '388', '451'],
#  ['thyrocare_0_8749.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '627',
#   '683',
#   '387',
#   '451'],
#  ['thyrocare_0_9047.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '39',
#   '421',
#   '343',
#   '563'],
#  ['thyrocare_0_9047.jpg', '1068', '635', 'Value', '687', '752', '342', '556'],
#  ['thyrocare_0_9047.jpg', '1068', '635', 'Units', '808', '887', '342', '556'],
#  ['thyrocare_0_9047.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '918',
#   '1002',
#   '345',
#   '557'],
#  ['thyrocare_0_912.jpg', '939', '631', 'Test Name', '9', '333', '397', '461'],
#  ['thyrocare_0_912.jpg', '939', '631', 'Value', '503', '552', '390', '448'],
#  ['thyrocare_0_912.jpg', '939', '631', 'Units', '606', '667', '389', '449'],
#  ['thyrocare_0_912.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '667',
#   '730',
#   '390',
#   '446'],
#  ['thyrocare_0_9207.jpg',
#   '1068',
#   '635',
#   'Test Name',
#   '21',
#   '415',
#   '342',
#   '564'],
#  ['thyrocare_0_9207.jpg', '1068', '635', 'Value', '690', '758', '342', '556'],
#  ['thyrocare_0_9207.jpg', '1068', '635', 'Units', '819', '897', '343', '553'],
#  ['thyrocare_0_9207.jpg',
#   '1068',
#   '635',
#   'Reference Range',
#   '929',
#   '1024',
#   '343',
#   '553'],
#  ['thyrocare_0_9447.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '105',
#   '367',
#   '426',
#   '509'],
#  ['thyrocare_0_9447.jpg', '939', '631', 'Value', '490', '539', '415', '498'],
#  ['thyrocare_0_9447.jpg', '939', '631', 'Units', '575', '627', '412', '494'],
#  ['thyrocare_0_9447.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '625',
#   '682',
#   '411',
#   '495'],
#  ['thyrocare_0_9575.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '76',
#   '357',
#   '408',
#   '481'],
#  ['thyrocare_0_9575.jpg', '939', '631', 'Value', '495', '540', '401', '472'],
#  ['thyrocare_0_9575.jpg', '939', '631', 'Units', '582', '637', '397', '469'],
#  ['thyrocare_0_9575.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '635',
#   '694',
#   '397',
#   '468'],
#  ['thyrocare_0_9691.jpg',
#   '939',
#   '631',
#   'Test Name',
#   '49',
#   '349',
#   '422',
#   '502'],
#  ['thyrocare_0_9691.jpg', '939', '631', 'Value', '497', '547', '411', '490'],
#  ['thyrocare_0_9691.jpg', '939', '631', 'Units', '591', '648', '410', '488'],
#  ['thyrocare_0_9691.jpg',
#   '939',
#   '631',
#   'Reference Range',
#   '649',
#   '709',
#   '409',
#   '486']]

# %%
# Convert the list to a DataFrame for easier manipulation and analysis
df = pd.DataFrame(data, columns = ['filename', 'width', 'height', 'name', 'xmin', 'xmax', 'ymin', 'ymax'])

# %%
# Display the first few rows of the DataFrame
df.head()
# Out:
#                filename width height             name xmin xmax ymin ymax
# 0   thyrocare_0_122.jpg   939    631        Test Name    1  329  399  463
# 1   thyrocare_0_122.jpg   939    631            Value  503  554  394  453
# 2   thyrocare_0_122.jpg   939    631            Units  607  671  392  450
# 3   thyrocare_0_122.jpg   939    631  Reference Range  672  736  392  450
# 4  thyrocare_0_1374.jpg  1068    635        Test Name   51  420  346  595

# %%
# Print the shape of the DataFrame (number of rows and columns)
df.shape
# Out:
# (236, 8)

# %%
# Count the occurrences of each object class (name) in the dataset
df['name'].value_counts()
# Out:
# name
# Test Name          59
# Value              59
# Units              59
# Reference Range    59
# Name: count, dtype: int64

# %%
# Check the structure of the DataFrame and data types of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  236 non-null    object
#  1   width     236 non-null    object
#  2   height    236 non-null    object
#  3   name      236 non-null    object
#  4   xmin      236 non-null    object
#  5   xmax      236 non-null    object
#  6   ymin      236 non-null    object
#  7   ymax      236 non-null    object
# dtypes: object(8)
# memory usage: 14.9+ KB

# %%
# Convert specific columns to integers for easier computation later
columns = ['width', 'height', 'xmin', 'xmax', 'ymin', 'ymax']
df[columns] = df[columns].astype(int)

# %%
# Re-check the DataFrame structure after type conversion
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  236 non-null    object
#  1   width     236 non-null    int64
#  2   height    236 non-null    int64
#  3   name      236 non-null    object
#  4   xmin      236 non-null    int64
#  5   xmax      236 non-null    int64
#  6   ymin      236 non-null    int64
#  7   ymax      236 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 14.9+ KB

# %%
# Calculate the center x and center y coordinates of each object (YOLO format)
df['center_x'] = ((df['xmax'] + df['xmin']) / 2) / df['width']
df['center_y'] = ((df['ymax'] + df['ymin']) / 2) / df['height']

# Calculate the normalized width and height of the bounding box (YOLO format)
df['w'] = (df['xmax'] - df['xmin']) / df['width']
df['h'] = (df['ymax'] - df['ymin']) / df['height']

# %%
# Display the first few rows of the updated DataFrame with new columns
df.head()
# Out:
#                filename  width  height             name  xmin  xmax  ymin  \
# 0   thyrocare_0_122.jpg    939     631        Test Name     1   329   399
# 1   thyrocare_0_122.jpg    939     631            Value   503   554   394
# 2   thyrocare_0_122.jpg    939     631            Units   607   671   392
# 3   thyrocare_0_122.jpg    939     631  Reference Range   672   736   392
# 4  thyrocare_0_1374.jpg   1068     635        Test Name    51   420   346
#
#    ymax  center_x  center_y         w         h
# 0   463  0.175719  0.683043  0.349308  0.101426
# 1   453  0.562833  0.671157  0.054313  0.093502
# 2   450  0.680511  0.667195  0.068158  0.091918
# 3   450  0.749734  0.667195  0.068158  0.091918
# 4   595  0.220506  0.740945  0.345506  0.392126

# %% [markdown]
# ### Split data into train and test

# %%
# Get the list of unique image filenames in the dataset
images = df['filename'].unique()

# %%
# Check the number of unique images
len(images)
# Out:
# 59

# %%
# Split the images into 80% for training and 20% for testing
images_df = pd.DataFrame(images, columns=['filename'])

# Randomly sample 80% of images for training
images_train = tuple(images_df.sample(frac=0.8)['filename'])

# %%
# Use the remaining 20% for testing
images_test = tuple(images_df.query(f'filename not in {images_train}')['filename'])

# %%
# Check the number of images in the training and testing sets
len(images_train), len(images_test)
# Out:
# (47, 12)

# %%
# Create separate DataFrames for training and testing data
train_df = df.query(f'filename in {images_train}')
test_df = df.query(f'filename in {images_test}')

# %%
# Display the first few rows of the training and testing DataFrames
train_df.head()
test_df.head()
# Out:
#                 filename  width  height             name  xmin  xmax  ymin  \
# 20  thyrocare_0_2300.jpg   1068     635        Test Name    93   431   348
# 21  thyrocare_0_2300.jpg   1068     635            Value   672   727   347
# 22  thyrocare_0_2300.jpg   1068     635            Units   779   850   348
# 23  thyrocare_0_2300.jpg   1068     635  Reference Range   877   955   349
# 48  thyrocare_0_3439.jpg    939     631        Test Name    68   351   399
#
#     ymax  center_x  center_y         w         h
# 20   606  0.245318  0.751181  0.316479  0.406299
# 21   599  0.654963  0.744882  0.051498  0.396850
# 22   598  0.762640  0.744882  0.066479  0.393701
# 23   596  0.857678  0.744094  0.073034  0.388976
# 48   464  0.223110  0.683835  0.301384  0.103011

# %% [markdown]
# ### Assign ID number to object names

# %%
# Function to encode object class names into numeric IDs (required for training)
def label_encoding(x):
    labels = {'Test Name': 0, 'Value': 1, 'Units': 2, 'Reference Range': 3}
    return labels[x]

# %%
# Apply label encoding to the training and testing sets
train_df['ID'] = train_df['name'].apply(label_encoding)
test_df['ID'] = test_df['name'].apply(label_encoding)
# Out:
# C:\Users\gaura\AppData\Local\Temp\ipykernel_15804\2312808435.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['ID'] = train_df['name'].apply(label_encoding)
# C:\Users\gaura\AppData\Local\Temp\ipykernel_15804\2312808435.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['ID'] = test_df['name'].apply(label_encoding)

# %%
# Check the updated training DataFrame with label IDs
train_df.head()
# Out:
#                filename  width  height             name  xmin  xmax  ymin  \
# 0   thyrocare_0_122.jpg    939     631        Test Name     1   329   399
# 1   thyrocare_0_122.jpg    939     631            Value   503   554   394
# 2   thyrocare_0_122.jpg    939     631            Units   607   671   392
# 3   thyrocare_0_122.jpg    939     631  Reference Range   672   736   392
# 4  thyrocare_0_1374.jpg   1068     635        Test Name    51   420   346
#
#    ymax  center_x  center_y         w         h  ID
# 0   463  0.175719  0.683043  0.349308  0.101426   0
# 1   453  0.562833  0.671157  0.054313  0.093502   1
# 2   450  0.680511  0.667195  0.068158  0.091918   2
# 3   450  0.749734  0.667195  0.068158  0.091918   3
# 4   595  0.220506  0.740945  0.345506  0.392126   0

# %% [markdown]
# ### Save images and label in text

# %%
# Create directories for storing training and testing images and labels
train_folder = 'datasets/images/train'
test_folder = 'datasets/images/test'

os.makedirs(train_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

# %%
# Specify columns to group by for creating individual label files for each image
columns = ['filename', 'ID', 'center_x', 'center_y', 'w', 'h']

# Group data by filename (for both training and testing datasets)
groupby_object_train = train_df[columns].groupby('filename')
groupby_object_test = test_df[columns].groupby('filename')

# %%
# Function to move images and save their corresponding labels in YOLO format
def save_data(filename, folder_path, group_object):
    # Move the image file to the destination folder
    source = os.path.join('datasets/images', filename)
    destination = os.path.join(folder_path, filename)
    move(source, destination)  # Move image to the train/test folder

    # Save the label data in a text file with the same name as the image
    text_filename = os.path.join(folder_path, os.path.splitext(filename)[0] + '.txt')
    
    # Save the grouped data in YOLO format (no header, space-separated)
    group_object.get_group(filename).set_index('filename').to_csv(text_filename, sep=' ', index=False, header=False)

# %%
# Apply the save_data function to each training image
filename_series = pd.Series(groupby_object_train.groups.keys())
filename_series.apply(save_data, args=(train_folder, groupby_object_train))
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# 27    None
# 28    None
# 29    None
# 30    None
# 31    None
# 32    None
# 33    None
# 34    None
# 35    None
# 36    None
# 37    None
# 38    None
# 39    None
# 40    None
# 41    None
# 42    None
# 43    None
# 44    None
# 45    None
# 46    None
# dtype: object

# %%
# Apply the save_data function to each testing image
filename_series = pd.Series(groupby_object_test.groups.keys())
filename_series.apply(save_data, args=(test_folder, groupby_object_test))
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# dtype: object
